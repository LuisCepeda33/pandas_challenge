# %% [markdown]
# # 00 Setup and Overview
#
# ## Learning objectives
#
# - understand the project workflow
# - generate the local synthetic datasets
# - preview the business scenario and file layout
# - save a small processed CSV file locally
#
# This project uses a small ecommerce scenario with customers, products, orders, and order items. The main coding work happens in `src/student_tasks.py`, and the notebooks help you practice the ideas step by step.

# %%
from pathlib import Path
import sys

ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks':
    ROOT = ROOT.parent
elif not (ROOT / 'src').exists():
    ROOT = ROOT.parent

if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

ROOT

# %% [markdown]
# ## Recommended workflow
#
# 1. Generate the datasets.
# 2. Work through the notebooks in order.
# 3. Implement the TODO functions in `src/student_tasks.py`.
# 4. Run `pytest` in the terminal.
#
# Validation hint: if the files in `data/raw/` do not exist yet, run the next cell once.

# %%
from src.data_generation import generate_all_datasets

generated = generate_all_datasets()
generated

# %%
import pandas as pd

customers = pd.read_csv(ROOT / 'data' / 'raw' / 'customers.csv')
orders = pd.read_csv(ROOT / 'data' / 'raw' / 'orders.csv')

print(customers.shape)
print(orders.shape)
customers.head()

# %% [markdown]
# ## Scenario snapshot
#
# Imagine this data belongs to a small ecommerce business. The business wants to understand customer behavior, order patterns, missing data issues, and product performance.
#
# You will practice on realistic edge cases:
#
# - missing values
# - duplicate rows
# - date columns
# - categorical columns
# - numeric columns
# - keys for joins

# %%
from src.exercise_utils import save_processed_csv

preview = orders[['order_id', 'customer_id', 'status', 'total_amount']].head(10)
saved_path = save_processed_csv(preview, 'orders_preview.csv')
saved_path

# %% [markdown]
# ## Next step
#
# Move to `01_dataframes_and_loading.ipynb` and start with DataFrame creation and CSV loading.
